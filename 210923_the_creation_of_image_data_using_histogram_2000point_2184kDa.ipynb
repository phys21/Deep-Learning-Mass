# %% [markdown]
# # The creation of image data using histogram

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# loading the data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("./210923_initial_freq_with_noise_2000point_2184kDa.csv")
print(df[0:1])
# Out:
#              0           1           2            3            4           5  \
# 0  26535109.67  26567167.6  26580894.5  26523390.32  26544546.73  26549089.2
#
#              6            7            8            9  ...         1990  \
# 0  26606633.83  26559716.62  26551873.79  26542373.09  ...  26574424.79
#
#           1991         1992         1993         1994         1995  \
# 0  26556233.82  26571904.03  26559480.19  26559012.86  26574381.18
#
#          1996         1997         1998         1999
# 0  26574947.1  26559634.91  26561185.55  26571405.26
#
# [1 rows x 2000 columns]

# %%
#표준정규화 (-1,1)
#scaler = StandardScaler()
#scaler.fit(data)
#Normalized = scaler.transform(data)
#print(Normalized)
#np.mean(Normalized)
#plt.hist(Normalized[2])
#plt.show()

# %% [markdown]
# change the data type to use in the source code

# %%
data = []
for i in range(1,5501):
    a = df[i-1:i].values
    b = a.flatten()
   # b = b.astype(int)
    data.append(b)
data[0]
# Out:
# array([26535109.67, 26567167.6 , 26580894.5 , ..., 26559634.91,
#        26561185.55, 26571405.26])

# %% [markdown]
# (type1)Draw the histogram for the initial resonance frequency with noise (all data is the initial value. in the next step, the difference of frequency will be applied to these data.)

# %%
for i in range(0,5499):
    fig = plt.figure(figsize = (3,4))
    plt.hist(data[i]) #, density=True, bins=100)
    plt.ylim(0,1000)
    plt.xlim(26450000,26630000)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b87a1d91d382> in <module>
#       4     plt.ylim(0,1000)
#       5     plt.xlim(26450000,26630000)
# ----> 6     plt.show()
#
# ~\Anaconda3\envs\py37\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~\Anaconda3\envs\py37\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~\Anaconda3\envs\py37\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
# ...

# %% [markdown]
# (type2)Draw the histogram for the initial resonance frequency with noise (all data is the initial value. in the next step, the difference of frequency will be applied to these data.)

# %%
for i in range(0,5499):
    plt.figure(figsize = (3,3))
    sns.distplot(data[i])
    plt.ylim(0,5e-5)
    plt.xlim(26450000,26630000)
    plt.show()
    #plt.savefig("./5000kDa/{i}.png".format(i=i))
# Out:
# C:\Users\User\Anaconda3\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\Anaconda3\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# (type1) Draw the histogram for the initial resonance frequency with noise for only one data

# %%
#데이터 타입 변경
b = df[0:1].values
a = b.flatten()
a = a.astype(int)
#c = np.bincount(a)
print(a)
# Out:
# [26535109 26567167 26580894 ... 26559634 26561185 26571405]

# %%
#히스토그램
fig = plt.figure(figsize = (3,3))
plt.hist(a)
plt.ylim(0,1000)
plt.xlim(26450000,26630000)
#plt.ylim(0,600)
plt.show()

# %% [markdown]
# (type2) Draw the histogram for the initial resonance frequency with noise for only one data

# %%
fig = plt.figure(figsize = (3,3))
sns.distplot(a)
plt.xlim(26450000,26630000)
#plt.ylim(0,600)
#plt.title()
plt.show()
# Out:
# C:\Users\User\Anaconda3\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Loading the data and Draw the histogram for the resonance frequency according to mass change

# %%
df1 = pd.read_csv("./210923_mass_freq_with_noise_2000point_2184kDa.csv")
print(df1[0:1])
# Out:
#              0            1            2            3            4  \
# 0  26579760.63  26568913.09  26560493.88  26536955.25  26559524.12
#
#              5            6            7            8            9  ...  \
# 0  26576497.13  26571660.81  26540487.24  26575319.76  26582895.94  ...
#
#           1990         1991         1992         1993         1994  \
# 0  26571694.02  26568414.13  26576611.03  26574030.04  26555292.93
#
#           1995         1996         1997         1998        1999
# 0  26560375.19  26558772.38  26541531.38  26570477.78  26565810.0
#
# [1 rows x 2000 columns]

# %% [markdown]
# Change the data type

# %%
data2 = []
for i in range(1,5501):
    c = df1[i-1:i].values
    d = c.flatten()
   # d = d.astype(int)
    data2.append(d)
#c = np.bincount(a)
print(data2[0])
# Out:
# [26579760.63 26568913.09 26560493.88 ... 26541531.38 26570477.78
#  26565810.  ]

# %%
len(data2)
# Out:
# 5500

# %% [markdown]
# (type1) Draw the histogram for the resonance frequency according to mass change and the compaison of graph difference

# %%
for i in range(0,5500):
    plt.figure(figsize = (3,3))
    sns.distplot(data2[i])
    plt.ylim(0,5e-5)
    plt.xlim(26450000,26630000)
    #plt.show()
    plt.savefig("./2184kDa unit/{i}.png".format(i=i))
# Out:
# C:\Users\User\Anaconda3\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\Anaconda3\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for i in range(0,11):
    plt.figure(figsize = (3,3))
    plt.hist(data2[i*499+2])
    plt.ylim(0,1000)
    plt.xlim(26450000,26630000)
    plt.show()

# %% [markdown]
# (type2) Draw the histogram for the resonance frequency according to mass change and the compaison of graph difference

# %%
for i in range(0,11):
    fig = plt.figure(figsize = (3,3))
    sns.distplot(data2[i*499+2])
    plt.ylim(0,5e-5)
    plt.xlim(26450000,26630000)
    plt.show()
# Out:
# C:\Users\User\Anaconda3\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\Anaconda3\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Draw the histogram and merged graphs for the resonance frequency according to mass change

# %%
data3 = []
for i in range(0,11):
    e = data2[i*499+2]
    data3.append(e)
print(data3[:])
# Out:
# [array([26586438.78, 26557985.04, 26600718.55, ..., 26552630.1 ,
#        26553269.41, 26550517.95]), array([26575759.34, 26551323.11, 26597124.6 , ..., 26571348.49,
#        26545594.19, 26567520.35]), array([26554155.25, 26595413.7 , 26539330.38, ..., 26577677.81,
#        26554641.32, 26561640.63]), array([26553865.53, 26552206.49, 26597521.33, ..., 26570279.96,
#        26532328.82, 26552200.53]), array([26556009.67, 26555170.05, 26564283.87, ..., 26586607.31,
#        26557336.43, 26545911.95]), array([26569371.98, 26556064.85, 26526430.96, ..., 26537445.46,
#        26566835.82, 26539233.03]), array([26556526.5 , 26552703.78, 26574509.51, ..., 26553093.39,
#        26528810.77, 26557647.88]), array([26543254.95, 26557569.17, 26548918.32, ..., 26542518.98,
#        26537895.23, 26568793.55]), array([26541229.51, 26550534.25, 26546610.89, ..., 26540235.53,
#        26542545.23, 26554313.95]), array([26577943.55, 26556263.03, 26523337.62, ..., 26573162.3 ,
# ...

# %%
for i in range(0,11):
    fig = plt.figure(figsize = (3,3))
    sns.distplot(data3[i])
    sns.distplot(a)
    plt.xlim(26450000,26630000)
    plt.show()
# Out:
# C:\Users\User\Anaconda3\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\Anaconda3\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for i in range(0,5500):
    fig = plt.figure(figsize = (3,3))
    sns.distplot(data3[i])
    sns.distplot(a)
    plt.ylim(0,5e-5)
    plt.xlim(26450000,26630000)
   #plt.show() 
    plt.savefig("./2184kDa mass/{i}".format(i=i))
# Out:
# C:\Users\User\Anaconda3\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\Anaconda3\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
